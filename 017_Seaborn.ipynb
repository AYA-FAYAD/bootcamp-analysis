# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pengu=sns.load_dataset("penguins")

# %%
#sns.scatterplot()
#-date=
#-x=
#-y=

# %%
sns.set_theme()

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.plot(kind="scatter",x="total_bill",y="tip")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="smoker")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="day")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",style="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",style="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",size="size")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",size="size")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
flight=sns.load_dataset("flights")
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=flight,x="year",y="passengers") # take mean evr for passenger by defult
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flight,x="year",y="passengers",estimator="sum") # in  lineplot he sort indexby defult
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
flight.groupby("year")["passengers"].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.lineplot(data=flight,x="year",y="passengers",hue="month")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
trips=sns.load_dataset("taxis",parse_dates=["pickup","dropoff"])

# %%
trips["hour"]= trips["pickup"].dt.hour

# %%
trips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.lineplot(data=trips, x="hour",y="total" ,hue="payment",style="color")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %%
sns.lineplot(data=trips, x="hour",y="total" ,hue="payment",style="color",ci=None)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x="total_bill",y="tip",kind="scatter",col="sex")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",kind="scatter",hue="smoker" ,col="sex",row="time")

# %%
sns.relplot(data=trips,x="hour",y="total",kind="line",col="pickup_borough",hue="payment")

# %%
sns.relplot(data=trips,
            x="hour",
            y="total",
            kind="line",
            col="pickup_borough",
            hue="payment",
            row="dropoff_borough")

# %%
sns.lineplot(data=flight,x="year",y="passengers",hue="month")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.relplot(data=tips,
            x="total_bill",
            y="tip",
            kind="scatter",
            col="sex",
            row="day",
            hue="smoker",
            height=2
           ) # hight it tall in inch

# %%
sns.relplot(data=tips,
            x="total_bill",
            y="tip",
            kind="scatter",
            col="sex",
            row="day",
            hue="smoker",
            height=7
           ) # hight it tall in inch

# %%
sns.relplot(data=tips,
            x="total_bill",
            y="tip",
            kind="scatter",
            col="sex",
            row="day",
            hue="smoker",
            height=2,
            aspect=2
           ) #aspect wid *hight by defult is 1

# %%
sns.histplot(data=tips, x="tip")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip" ,hue="time")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip" ,hue="smoker",multiple="stack")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip" ,hue="smoker",multiple="dodge")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=pengu,x="body_mass_g",bins=10)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=pengu,x="body_mass_g",bins=10,binwidth=2)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=pengu,x="body_mass_g",bins=10,hue="species",multiple="stack")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=pengu,x="body_mass_g",bins=10,hue="species",multiple="stack",element="step")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=pengu,x="body_mass_g",bins=10,hue="species",multiple="stack",kde=True)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip",kde=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.kdeplot(data=pengu,x="body_mass_g",hue="species",bw_adjust=0.4)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=pengu,x="body_mass_g",hue="species",bw_adjust=0.4)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
pengu
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data=pengu, x="flipper_length_mm" )
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=pengu, x="body_mass_g")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=pengu, x="body_mass_g",y="flipper_length_mm"  )
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=pengu, x="body_mass_g",y="flipper_length_mm"  )
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.histplot(data=pengu, x="body_mass_g",y="flipper_length_mm",hue="species" )
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=pengu, x="bill_length_mm",y="flipper_length_mm",hue="species" )
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.rugplot(data=tips,x="tip",height=1)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.rugplot(data=tips,y="tip",height=0.2)
# Out:
# <AxesSubplot:ylabel='tip'>

# %%
sns.kdeplot(data=tips, x="total_bill")
sns.rugplot(data=tips, x="total_bill")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip")
sns.rugplot(data=tips, x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
diamonds = sns.load_dataset("diamonds")
sns.scatterplot(data=diamonds, x="carat", y="price", s=5)
sns.rugplot(data=diamonds, x="carat", y="price", lw=1, alpha=.005)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.displot(kind="hist", data=pengu, x="body_mass_g", height=3, aspect=2)

# %%
sns.displot(
    kind="hist",
    hue="sex",
    data=pengu,
    x="body_mass_g",
    col="species",
    
    
)

# %%
sns.displot(data=tips,kind="kde",x="tip",col="time",rug=True)

# %%
sns.displot(data=tips, kind="kde", x="total_bill", y="tip", rug=True)

# %%
sns.countplot(data=pengu, x="species")
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
pengu["species"].value_counts().plot(kind="bar",color=["red","green","orange"])
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=pengu, x="species",hue="sex")
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
titanc=pd.read_csv("data/titanic.csv")

# %%
sns.countplot(data=titanc,x="pclass",hue="sex")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanc,y="pclass",hue="sex")
# Out:
# <AxesSubplot:xlabel='count', ylabel='pclass'>

# %%
sns.scatterplot(data=trips,x="pickup_borough")
# Out:
# <AxesSubplot:xlabel='pickup_borough'>

# %%
sns.scatterplot(data=trips, x="pickup_borough" ,y="distance")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
sns.stripplot(data=trips, x="pickup_borough" ,y="distance")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
sns.stripplot(data=trips, x="pickup_borough" ,y="distance")

# %%
trips.sample=trips.nlargest(600,"total")

# %%
plt.figure(figsize=(12,5))# to aviod overlapping
sns.swarmplot(data=trips.sample, x="pickup_borough" ,y="distance")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
plt.figure(figsize=(12,5))# to aviod overlapping
sns.stripplot(data=trips.sample, x="pickup_borough" ,y="distance")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
titanic=sns.load_dataset("titanic")

# %%
sns.stripplot(data=titanic , x="pclass" ,y="age")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=titanic , x="pclass" ,y="age" ,hue="sex")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=titanic ,x="age")
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(data=trips ,x="pickup_borough", y="total")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.boxplot(data=trips ,x="pickup_borough", y="total" , whis=2)
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.boxplot(data=titanic, x="pclass", y="age")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=titanic, x="pclass", y="age" ,hue="sex")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=pengu ,x="species" ,y="body_mass_g")
sns.swarmplot(data=pengu ,x="species" ,y="body_mass_g",color= "0.3")
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxplot(data=trips ,x="pickup_borough", y="total")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(data=trips ,x="pickup_borough", y="total")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.violinplot(data=titanic ,x="age")
#sns.boxplot(data=titanic ,x="age")
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.violinplot(data=titanic ,x="pclass" ,y="age")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.violinplot(data=titanic ,y="pclass" ,x="age")
# Out:
# <AxesSubplot:xlabel='age', ylabel='pclass'>

# %%
sns.violinplot(data=titanic ,x="pclass" ,y="age" ,hue="sex")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.violinplot(data=titanic ,x="pclass" ,y="age" ,hue="sex",split=True)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.barplot(data=trips ,x="pickup_borough",y="distance")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
sns.barplot(data=trips ,x="pickup_borough",y="total", estimator=sum)
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
trips.groupby("pickup_borough")["total"].sum().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='pickup_borough'>

# %%
sns.barplot(data=trips ,x="pickup_borough",y="total",hue="color")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.violinplot(data=trips ,x="pickup_borough",y="total",hue="color",split=True)
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.barplot(data=trips ,x="pickup_borough",y="total",hue="color",dodge=False)
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.catplot(data=titanic ,x="sex",y="survived",kind="bar")

# %%
sns.catplot(data=titanic ,x="sex",y="survived",kind="bar", col="pclass")

# %%
sns.catplot(data=titanic ,x="sex",y="survived",kind="bar",hue="sex")

# %%
sns.catplot(data=trips,kind="strip",x="pickup_borough",y="distance" ,col="color")

# %%
sns.catplot(data=trips,kind="violin",x="pickup_borough",y="distance" ,col="color",split=True)

# %%
sns.catplot(data=trips,
            kind="strip",
            x="pickup_borough",
            y="distance" ,
            col="color",
            aspect=2
           )

# %%
sns.catplot(
    data=titanic, 
    kind="bar",
    x="who",
    y="survived",
    col="pclass",
    ci=None,
)
