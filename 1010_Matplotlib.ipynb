# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2,4,6,8]) # if inter singel value its will treat is as y and x by defult start by one

# %%
sa=[5500,65000,72000,9000,115000,150000]
age=[20,25,30,32,40,45]
plt.plot(age,sa)

# %%
plt.plot(age,sa)
plt.show()  # show method when use pyton to show the figer

# %%
import numpy as np 
num=np.arange(5)
num*2
# Out:
# array([0, 2, 4, 6, 8])

# %%
plt.plot(num,num)
plt.plot(num, num*num)
plt.plot(num, num**3)

# %%
plt.figure()
plt.plot(num,num)
plt.figure() #### spreat
plt.plot(num, num*num)
plt.plot(num, num**3)

# %%
plt.figure()
plt.plot(num,num)
plt.figure() ##new empty figure
plt.plot(num, num*num)
plt.figure()
plt.plot(num, num**3)

# %%
plt.figure(figsize=(2,6) ,dpi=200)
#(with,tall) dipi parameter for controlle bicsel for inch
plt.plot(num,num)

# %%
plt.figure(figsize=(2,6) )
plt.plot(num,num**3)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
plt.plot(num,num)
plt.plot(num, num*num)
plt.plot(num, num**3)

# %%
plt.style.use('seaborn')

# %%
plt.plot(num,num)
plt.plot(num, num*num)
plt.plot(num, num**3)

# %%
plt.style.use('Solarize_Light2')

# %%
plt.plot(num,num)
plt.plot(num, num*num)
plt.plot(num, num**3)

# %%
plt.plot(num,num ,color="red")
plt.plot(num, num*num, color="#e84393")
plt.plot(num, num**3 , c="#2d3436", linewidth=4)

# %%
plt.plot(num,num ,color="red")
plt.plot(num, num*num, color="#e84393", linestyle="dotted")
plt.plot(num, num**3 , c="#2d3436", linewidth=4 , linestyle="--")

# %%
plt.plot(num,num ,color="red" ,marker="*", markersize=20 , markerfacecolor="#34495e")

# %%
plt.style.use('seaborn')

# %%
sa=[5500,65000,72000,9000,115000,150000]
age=[20,25,30,32,40,45]
plt.plot(age,sa)
plt.title("my noo")
plt.figure()
plt.plot(num,num ,color="red" ,marker="*", markersize=20 , markerfacecolor="#34495e")
plt.title("good lufy" , loc="right")
# Out:
# Text(1.0, 1.0, 'good lufy')

# %%
sa=[5500,65000,72000,9000,115000,150000]
age=[20,25,30,32,40,45]
plt.plot(age,sa)
plt.title("my noo" , fontsize=24 ,color="#81ecec")
plt.xlabel("age", labelpad=90) # make the lebal much lower
plt.ylabel("sa", labelpad=30 ,fontsize=24)
# Out:
# Text(0, 0.5, 'sa')

# %%
plt.figure(figsize=(5,5))
sa=[5500,65000,72000,9000,115000,150000]
age=[20,25,30,32,40,45]
plt.plot(age,sa)
plt.title("my noo" , fontsize=24 ,color="#81ecec")
plt.xlabel("age", labelpad=90) # make the lebal much lower
plt.ylabel("sa", labelpad=30 ,fontsize=24) 
plt.xticks([20,30,40,50])
plt.yticks([6000, 150000] , labels=["60k" ,"150k"])
# Out:
# ([<matplotlib.axis.YTick at 0x252d38db160>,
# ...
#  [Text(0, 6000, '60k'), Text(0, 150000, '150k')])

# %%
plt.figure(figsize=(5,5))
sa=[5500,65000,72000,9000,115000,150000]
age=[20,25,30,32,40,45]
plt.plot(age,sa)
plt.title("my noo" , fontsize=24 ,color="#81ecec")
plt.xlabel("age", labelpad=90) # make the lebal much lower
plt.ylabel("sa", labelpad=30 ,fontsize=24) 
plt.xticks([20,30,40,50])
plt.yticks([6000, 150000] , labels=["60k" ,"150k"])
plt.xlim(25,45)
# Out:
# (25.0, 45.0)

# %%
plt.figure(figsize=(8,8))
plt.plot(num, color="#e84393",label="x" )
plt.plot(num**2, color="#00b894",label="x2")
plt.plot(num**3, color="#636e72" ,label="x3")
plt.legend()

# %%
plt.figure(figsize=(8,8))
plt.plot(num, color="#e84393",label="x" )
plt.plot(num**2, color="#00b894",label="x2")
plt.plot(num**3, color="#636e72" ,label="x3")
plt.legend(loc="center left" , shadow=True , frameon=True, facecolor="#a29bfe")

# %%
plants = ['Spinach', 'Turnip', 'Rhubarb', 'Broccoli', 'Kale']
died = [10,25,5,30,21]
germinated = [74, 88, 56,69,59]

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, germinated, width=0.6 ,color="#eb4d4b")
plt.title("germanation rate" ,fontsize=24 ,color="#ff7979")
plt.ylabel("nseed" ,fontsize=15 , color="#0984e3")
# Out:
# Text(0, 0.5, 'nseed')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, width=0.6 ,color="#e056fd")
plt.title("died" ,fontsize=24 ,color="#ff7979")
plt.ylabel("nseed" ,fontsize=15 , color="#0984e3")
# Out:
# Text(0, 0.5, 'nseed')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, germinated, width=0.4 ,color="#eb4d4b",align= 'edge')
plt.bar(plants, died, width=0.4 ,color="#e056fd" )
plt.title("all" ,fontsize=24 ,color="#ff7979")
plt.ylabel("nseed" ,fontsize=15 , color="#0984e3")
# Out:
# Text(0, 0.5, 'nseed')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, germinated, width=0.4 ,color="#eb4d4b", label="live")
plt.bar(plants, died, width=0.4 ,color="#e056fd" ,bottom=germinated ,label="dided")
plt.title("all" ,fontsize=24 ,color="#ff7979")
plt.ylabel("nseed" ,fontsize=15 , color="#0984e3")
plt.legend(shadow=True ,frameon=True,facecolor="white")

# %%
plt.figure(figsize=(6,6))
plt.barh(plants, died ,color="#e056fd" )
# Out:
# <BarContainer object of 5 artists>

# %%
plt.hist([2,2,2,4,4,2,4,1,2,4,3,3,3,2,1,1])
# Out:
# (array([3., 0., 0., 6., 0., 0., 3., 0., 0., 4.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
nums=np.random.randn(100)
plt.hist(nums)
# Out:
# (array([ 6.,  5.,  8., 13., 19., 17., 16.,  8.,  5.,  3.]),
#  array([-1.90048005, -1.51356247, -1.1266449 , -0.73972733, -0.35280975,
#          0.03410782,  0.42102539,  0.80794297,  1.19486054,  1.58177811,
#          1.96869569]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(nums,bins=15, color="red")
# Out:
# (array([ 3.,  4.,  4.,  6.,  3., 12., 11., 15., 10., 10.,  6.,  8.,  1.,
#          6.,  1.]),
#  array([-1.90048005, -1.642535  , -1.38458995, -1.1266449 , -0.86869985,
#         -0.6107548 , -0.35280975, -0.0948647 ,  0.16308035,  0.42102539,
#          0.67897044,  0.93691549,  1.19486054,  1.45280559,  1.71075064,
#          1.96869569]),
#  <BarContainer object of 15 artists>)

# %%
import pandas as pd
tit=pd.read_csv("data/titanic.csv")
tit["age"]= pd.to_numeric(tit["age"],errors="coerce")

# %%
plt.hist(tit["age"])
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
firstc=tit[tit["pclass"]==1]["age"]
secc=tit[tit["pclass"]==2]["age"]
thirec=tit[tit["pclass"]==3]["age"]
plt.hist(firstc ,label="1class",alpha=0.5,color="#f9ca24")
plt.hist(secc ,label="2class",alpha=0.5,color="#30336b")
plt.hist(thirec,label="3class",alpha=0.5,color="#eb4d4b")
plt.legend()

# %%
heights = [137,140,142,145,147,150,152,155,157,160]
f_weights = [28.5,30.8,32.6,34.9,36.4,39,40.8,43.1,44.9,47.2]
m_weights = [34.9,38.1,33.5,35.8,46.7, 42.8,43.1,45.8,50.8,58.9]

# %%
plt.scatter(heights ,f_weights ,c="#be2edd",marker="+",label="female")
plt.scatter(heights ,m_weights,c="#6ab04c" ,marker="d",label="male")
plt.legend()
plt.xlabel("hight cm")
plt.ylabel("wight kg")
# Out:
# Text(0, 0.5, 'wight kg')

# %%
labels = ["Turkey", "Potatoes", "Pumpkin Pie", "Stuffing" ]
prices = [25.99,3.24,9.50, 6.99]

# %%
plt.pie(prices ,labels=labels,autopct="%1.1f%%",shadow=True, explode=(0,0,0.2,0))  #"%1.1f%%" format string to get the precentge 1dejet after dismel point
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["225 g flour",
          "90 g sugar",
          "1 egg",
          "60 g butter",
          "100 ml milk",
          "1/2 package of yeast"]

data = [225, 90, 50, 60, 100, 5]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %%
recipe = ["225 g flour",
          "90 g sugar",
          "1 egg",
          "60 g butter",
          "100 ml milk",
          "1/2 package of yeast"]

data = [225, 90, 50, 60, 100, 5]

# %%
plt.pie(data,labels=recipe,wedgeprops=dict(width=0.5),startangle=-40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1084/713772347.py in <module>
#       1 plt.pie(data,labels=recipe,wedgeprops=dict(width=0.5),startangle=-40)
# ----> 2 plt.label(shadow=True ,frameon=True,facecolor="white")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'label'

# %%
nums = np.arange(5)
plt.figure(figsize=(10,4))
plt.suptitle("alll",fontsize=30)
plt.subplot(1,3,1)
plt.title("x")
plt.plot(nums,nums)
plt.subplot(1,3,2)
plt.title("x2")
plt.plot(nums,nums**2,color="red")
plt.subplot(1,3,3)
plt.title("x3")
plt.plot(nums,nums**3,color="#be2edd")
plt.tight_layout() # to sure we havent any overlapped
plt.show()

# %%
nums = np.arange(5)
plt.figure(figsize=(4,10))
plt.suptitle("alll",fontsize=30)
plt.subplot(3,1,1)
plt.title("x")
plt.plot(nums,nums)
plt.subplot(3,1,2)
plt.title("x2")
plt.plot(nums,nums**2,color="red")
plt.subplot(3,1,3)
plt.title("x3")
plt.plot(nums,nums**3,color="#be2edd")
plt.tight_layout() # to sure we havent any overlapped
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
plt.plot(nums)


plt.subplot(2,2,2)
plt.plot(nums)

plt.subplot(2,2,3)
plt.plot(nums) #3axise on one figer

# %%
firstc=tit[tit["pclass"]==1]["age"]
secc=tit[tit["pclass"]==2]["age"]
thirec=tit[tit["pclass"]==3]["age"]

plt.figure(figsize=(10,4))
plt.suptitle("alll")
plt.subplot(1,3,1)
plt.title("1c")
plt.hist(firstc ,label="1class",color="#f9ca24")
plt.subplot(1,3,2)
plt.title("2c")
plt.hist(secc ,label="2class",color="#30336b")
plt.subplot(1,3,3)
plt.title("3c")
plt.hist(thirec,label="3class",color="#eb4d4b")
plt.tight_layout() # to sure we havent any overlapped
plt.show()

# %%
firstc=tit[tit["pclass"]==1]["age"]
secc=tit[tit["pclass"]==2]["age"]
thirec=tit[tit["pclass"]==3]["age"]

plt.figure(figsize=(10,4))
plt.suptitle("alll")
ax=plt.subplot(1,3,1)
plt.title("1c")
plt.hist(firstc ,label="1class",color="#f9ca24")
plt.subplot(1,3,2,sharey=ax)
plt.title("2c")
plt.hist(secc ,label="2class",color="#30336b")
plt.subplot(1,3,3,sharey=ax)
plt.title("3c")
plt.hist(thirec,label="3class",color="#eb4d4b")
plt.tight_layout() # to sure we havent any overlapped
plt.show()
